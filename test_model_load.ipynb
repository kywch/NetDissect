# %%
MODEL_FILE = 'checkpoint_001_14001.pth.tar'

# %%
import torch
checkpoint = torch.load(MODEL_FILE)





#print(checkpoint['state_dict'].keys())
state_dict = {k[2:]: v for k,v in checkpoint['state_dict'].items()}
print(state_dict)
# Out:
# {'conv1.weight':
# (0 ,0 ,.,.) =
#   2.7725e-02 -1.5701e-02  2.2614e-02  ...   2.5201e-04  4.4739e-02  1.6998e-02
#   1.1948e-02  2.2888e-02  9.6464e-04  ...  -2.7344e-02  8.7509e-03  1.7166e-02
#  -5.1086e-02  3.6499e-02 -2.0554e-02  ...  -2.5558e-02 -3.3661e-02 -2.2049e-02
#                  ...                   ⋱                   ...
#  -4.3610e-02 -2.6352e-02 -7.1411e-02  ...  -1.0327e-01 -9.6985e-02 -6.7261e-02
#  -4.3121e-02 -8.5632e-02 -1.0876e-01  ...  -7.8003e-02 -9.2590e-02 -7.1350e-02
#  -9.9609e-02 -1.1798e-01 -6.6040e-02  ...  -1.0803e-01 -8.0811e-02 -4.6478e-02
#
# (0 ,1 ,.,.) =
#   2.1957e-02 -3.4271e-02  3.9642e-02  ...  -1.2939e-02  6.6643e-03  4.5593e-02
#   2.5009e-02  3.9337e-02  3.1860e-02  ...  -9.8343e-03 -9.3231e-03  4.8645e-02
#  -1.8585e-02 -1.4982e-03 -2.3392e-02  ...  -4.6814e-02 -2.2064e-02 -2.0462e-02
#                  ...                   ⋱                   ...
#  -2.2934e-02 -6.4011e-03 -5.7556e-02  ...  -6.1432e-02 -6.0852e-02 -6.0516e-02
# ...

# %%
checkpoint["arch"]
# Out:
# 'resnet50'

# %%
checkpoint
# Out:
# {'epoch': 1,
#  'iteration': 14001,
#  'arch': 'resnet50',
#  'state_dict': OrderedDict([('1.conv1.weight',
#                (0 ,0 ,.,.) =
#                  2.7725e-02 -1.5701e-02  2.2614e-02  ...   2.5201e-04  4.4739e-02  1.6998e-02
#                  1.1948e-02  2.2888e-02  9.6464e-04  ...  -2.7344e-02  8.7509e-03  1.7166e-02
#                 -5.1086e-02  3.6499e-02 -2.0554e-02  ...  -2.5558e-02 -3.3661e-02 -2.2049e-02
#                                 ...                   ⋱                   ...
#                 -4.3610e-02 -2.6352e-02 -7.1411e-02  ...  -1.0327e-01 -9.6985e-02 -6.7261e-02
#                 -4.3121e-02 -8.5632e-02 -1.0876e-01  ...  -7.8003e-02 -9.2590e-02 -7.1350e-02
#                 -9.9609e-02 -1.1798e-01 -6.6040e-02  ...  -1.0803e-01 -8.0811e-02 -4.6478e-02
#
#                (0 ,1 ,.,.) =
#                  2.1957e-02 -3.4271e-02  3.9642e-02  ...  -1.2939e-02  6.6643e-03  4.5593e-02
# ...
